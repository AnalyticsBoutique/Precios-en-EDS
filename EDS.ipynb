# %% [markdown]
# # IMPORTADOR DE ESTACIONES DE SERVICIO Y PRECIOS POR ESTACIÓN Y PROMEDIO NACIONAL Y POR ESTADO
#
# Actualización al 1 de septiembre de 2021
#
# https://analyticsboutique.github.io/dashboard-simplificado/
#
# Fuentes de datos:
#
# https://datos.gob.mx/busca/dataset/estaciones-de-servicio-gasolineras-y-precios-finales-de-gasolina-y-diesel
#
# http://www.cre.gob.mx/da/PreciosPromedioMensuales.csv

# %%
# Dependencies
import pandas as pd
import xml.etree.ElementTree as ET
from xml.etree.ElementTree import parse
import json
from urllib.request import urlopen
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
from datetime import date
import requests

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### NOTA IMPORTANTE: Cambiar fecha del archivo a procesar

# %%
# Modificar diariamente
#Fecha = '2021.08.19' 

today = date.today()

if len(str(today.month)) == 1:
    Fecha = str(today.year) + '.0' + str(today.month) + '.' + str(today.day)
else:
    Fecha = str(today.year) + '.' + str(today.month) + '.' + str(today.day)

# Promedios estatates
#Year = 2021

#Month = 7

# %% [markdown]
# # SECCIÓN I:
#
# # Importador de datos de Estaciones de Servicio

# %%
# 
#tree = ET.parse('../Data_Raw/places_'+ Fecha +'.xml')

#
var_url = urlopen('https://bit.ly/2V1Z3sm') 
tree = ET.parse(var_url)

#
root = tree.getroot()
#root

# %%
# Extraemos los elementos del XML
ID = []
name = []
cre_id = []
lng = []
lat = []

for item in range (0,len(root)):
    ID.append(root[item].attrib['place_id'])
    name.append(root[item][0].text)
    cre_id.append(root[item][1].text)
    lng.append(root[item][2][0].text)
    lat.append(root[item][2][1].text)

# %%
# Imprime el número de registros
print(len(ID),len(name),len(cre_id),len(lat),len(lng))
# Out:
# 14611 14611 14611 14611 14611

# %%
# Convertimos a DATAFRAME
Gasolinerias = pd.DataFrame({ 'ID' : ID, 'name' : name, 'cre_id' : cre_id, 'lat' : lat, 'lng' : lng })
Gasolinerias.head()
# Out:
#      ID                                name              cre_id       lat  \
# 0  2039    ESTACION HIPODROMO, S.A. DE C.V.  PL/658/EXP/ES/2015  32.47641
# 1  2040  LAS MEJORES ESTACIONES, S.A DE C.V  PL/902/EXP/ES/2015   20.3037
# 2  2041              DIAZ GAS, S.A. DE C.V.  PL/760/EXP/ES/2015  31.71947
# 3  2042         COMBU-EXPRESS, S.A. DE C.V.  PL/825/EXP/ES/2015  20.71413
# 4  2043              PETROMAX, S.A. DE C.V.  PL/585/EXP/ES/2015  26.03787
#
#          lng
# 0  -116.9214
# 1  -99.74484
# 2  -106.4514
# 3  -103.3042
# 4  -98.29977

# %%
# Guardamos en CSV
Gasolinerias.to_csv('../Data_CSV/places_'+ Fecha +'.csv', sep = ',', encoding = 'utf-8-sig', index = False)

# %% [markdown]
# # Importador de datos de Precios de Gasolina en Estaciones de Servicio

# %%
# 
#tree = ET.parse('../Data_Raw/prices_'+ Fecha +'.xml')

#
var_url = urlopen('https://bit.ly/2JNcTha') 
tree = ET.parse(var_url)

#
root = tree.getroot()
#root

# %%
# Extraemos los elementos del XML
ID = []
tipo = []
gas_price = []

for item in range (0,len(root)):
    ID.append(root[item].attrib['place_id'])
    tipo.append(root[item][0].attrib['type']) 
    gas_price.append(root[item].findtext('gas_price'))

# %%
# Imprime el número de registros
print(len(ID),len(tipo),len(gas_price))
# Out:
# 17633 17633 17633

# %%
# Convertimos a DATAFRAME
Precios = pd.DataFrame({ 'ID' : ID, 'tipo' : tipo, 'gas_price' : gas_price })
Precios.head()
# Out:
#       ID     tipo gas_price
# 0  11703  regular     22.95
# 1  11702   diesel      27.7
# 2  11702  premium     26.75
# 3  11702  regular      24.3
# 4  11701  regular      18.5

# %%
# Guardamos en CSV
Precios.to_csv('../Data_CSV/precios_'+ Fecha +'.csv', sep = ',', encoding = 'utf-8-sig', index = False)

# %% [markdown]
# # Juntamos datos de Estaciones de Servicio, Precios de Gasolina y Franquicia

# %%
# Selecccionamos por tipo de gasolina
Precios_regular = Precios[Precios['tipo'] == 'regular']
Precios_regular.head()
# Out:
#       ID     tipo gas_price
# 0  11703  regular     22.95
# 3  11702  regular      24.3
# 4  11701  regular      18.5
# 5  11700  regular     23.58
# 6  11699  regular     23.99

# %%
# Selecccionamos por tipo de gasolina
Precios_premium = Precios[Precios['tipo'] == 'premium']
Precios_premium.head()
# Out:
#        ID     tipo gas_price
# 2   11702  premium     26.75
# 11  11696  premium     24.14
# 23  11394  premium     25.99
# 37  11384  premium     25.79
# 40  11383  premium     24.49

# %%
# Selecccionamos por tipo de gasolina
Precios_diesel = Precios[Precios['tipo'] == 'diesel']
Precios_diesel.head()
# Out:
#        ID    tipo gas_price
# 1   11702  diesel      27.7
# 8   11698  diesel      26.5
# 10  11696  diesel     24.44
# 20  11395  diesel     26.54
# 22  11394  diesel     25.39

# %%
# Juntamos datos:

# Regular
Gasolinerias_Precios = Gasolinerias

Gasolinerias_Precios = pd.merge(Gasolinerias_Precios, Precios_regular, on = 'ID', how='outer')

Gasolinerias_Precios = Gasolinerias_Precios.rename(columns={'gas_price': 'regular'})

Gasolinerias_Precios = Gasolinerias_Precios[['ID', 'name', 'cre_id', 'lat', 'lng', 'regular']]

Gasolinerias_Precios.head()
# Out:
#      ID                                name              cre_id       lat  \
# 0  2039    ESTACION HIPODROMO, S.A. DE C.V.  PL/658/EXP/ES/2015  32.47641
# 1  2040  LAS MEJORES ESTACIONES, S.A DE C.V  PL/902/EXP/ES/2015   20.3037
# 2  2041              DIAZ GAS, S.A. DE C.V.  PL/760/EXP/ES/2015  31.71947
# 3  2042         COMBU-EXPRESS, S.A. DE C.V.  PL/825/EXP/ES/2015  20.71413
# 4  2043              PETROMAX, S.A. DE C.V.  PL/585/EXP/ES/2015  26.03787
#
#          lng regular
# 0  -116.9214   21.99
# 1  -99.74484   23.89
# 2  -106.4514   18.87
# 3  -103.3042   23.99
# 4  -98.29977   20.99

# %%
# Premium
Gasolinerias_Precios = pd.merge(Gasolinerias_Precios, Precios_premium, on = 'ID', how='outer')

Gasolinerias_Precios = Gasolinerias_Precios.rename(columns={'gas_price': 'premium'})

Gasolinerias_Precios = Gasolinerias_Precios[['ID', 'name', 'cre_id', 'lat', 'lng', 'regular', 'premium']]

Gasolinerias_Precios.head()
# Out:
#      ID                                name              cre_id       lat  \
# 0  2039    ESTACION HIPODROMO, S.A. DE C.V.  PL/658/EXP/ES/2015  32.47641
# 1  2040  LAS MEJORES ESTACIONES, S.A DE C.V  PL/902/EXP/ES/2015   20.3037
# 2  2041              DIAZ GAS, S.A. DE C.V.  PL/760/EXP/ES/2015  31.71947
# 3  2042         COMBU-EXPRESS, S.A. DE C.V.  PL/825/EXP/ES/2015  20.71413
# 4  2043              PETROMAX, S.A. DE C.V.  PL/585/EXP/ES/2015  26.03787
#
#          lng regular premium
# 0  -116.9214   21.99   26.99
# 1  -99.74484   23.89   25.49
# 2  -106.4514   18.87     NaN
# 3  -103.3042   23.99     NaN
# 4  -98.29977   20.99     NaN

# %%
# Regular
Gasolinerias_Precios = pd.merge(Gasolinerias_Precios, Precios_diesel, on = 'ID', how='outer')

Gasolinerias_Precios = Gasolinerias_Precios.rename(columns={'gas_price': 'diesel'})

Gasolinerias_Precios = Gasolinerias_Precios[['ID', 'name', 'cre_id', 'lat', 'lng', 'regular', 'premium', 'diesel']]

Gasolinerias_Precios.head()
# Out:
#      ID                                name              cre_id       lat  \
# 0  2039    ESTACION HIPODROMO, S.A. DE C.V.  PL/658/EXP/ES/2015  32.47641
# 1  2040  LAS MEJORES ESTACIONES, S.A DE C.V  PL/902/EXP/ES/2015   20.3037
# 2  2041              DIAZ GAS, S.A. DE C.V.  PL/760/EXP/ES/2015  31.71947
# 3  2042         COMBU-EXPRESS, S.A. DE C.V.  PL/825/EXP/ES/2015  20.71413
# 4  2043              PETROMAX, S.A. DE C.V.  PL/585/EXP/ES/2015  26.03787
#
#          lng regular premium diesel
# 0  -116.9214   21.99   26.99    NaN
# 1  -99.74484   23.89   25.49    NaN
# 2  -106.4514   18.87     NaN    NaN
# 3  -103.3042   23.99     NaN    NaN
# 4  -98.29977   20.99     NaN    NaN

# %%
# Is NA's y revisar

Gasolinerias_Precios[Gasolinerias_Precios['cre_id'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, name, cre_id, lat, lng, regular, premium, diesel]
# Index: []

# %%
# Lectura de la base de franquicias:
Gasolinerias_Franquicias = pd.read_csv('../Data_CSV/Base_Franquicias_2020.10.08.csv')

Gasolinerias_Franquicias = Gasolinerias_Franquicias.rename(columns={'ID_CRE': 'ID'})

Gasolinerias_Franquicias.head()
# Out:
#      ID Franquicia_Marca
# 0  2039            PEMEX
# 1  2040             PERC
# 2  2041            PEMEX
# 3  2042    Combu-Express
# 4  2043      Petro Seven

# %%
# Convertimos ID en número
Gasolinerias_Precios['ID'] = pd.to_numeric(Gasolinerias_Precios['ID'])

Gasolinerias_Precios.dtypes
# Out:
# ID          int64
# name       object
# cre_id     object
# lat        object
# lng        object
# regular    object
# premium    object
# diesel     object
# dtype: object

# %%
# Verificamos el tipo de dato del ID
Gasolinerias_Franquicias.dtypes
# Out:
# ID                   int64
# Franquicia_Marca    object
# dtype: object

# %%
# Unión con la base de precios:
Gasolinerias_Precios = pd.merge(Gasolinerias_Precios, Gasolinerias_Franquicias, on = 'ID', how='outer')

Gasolinerias_Precios.head()
# Out:
#      ID                                name              cre_id       lat  \
# 0  2039    ESTACION HIPODROMO, S.A. DE C.V.  PL/658/EXP/ES/2015  32.47641
# 1  2040  LAS MEJORES ESTACIONES, S.A DE C.V  PL/902/EXP/ES/2015   20.3037
# 2  2041              DIAZ GAS, S.A. DE C.V.  PL/760/EXP/ES/2015  31.71947
# 3  2042         COMBU-EXPRESS, S.A. DE C.V.  PL/825/EXP/ES/2015  20.71413
# 4  2043              PETROMAX, S.A. DE C.V.  PL/585/EXP/ES/2015  26.03787
#
#          lng regular premium diesel Franquicia_Marca
# 0  -116.9214   21.99   26.99    NaN            PEMEX
# 1  -99.74484   23.89   25.49    NaN             PERC
# 2  -106.4514   18.87     NaN    NaN            PEMEX
# 3  -103.3042   23.99     NaN    NaN    Combu-Express
# 4  -98.29977   20.99     NaN    NaN      Petro Seven

# %%
# Is NA's y revisar

Gasolinerias_Precios[Gasolinerias_Precios['ID'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, name, cre_id, lat, lng, regular, premium, diesel, Franquicia_Marca]
# Index: []

# %%
Gasolinerias_Precios.head()
# Out:
#      ID                                name              cre_id       lat  \
# 0  2039    ESTACION HIPODROMO, S.A. DE C.V.  PL/658/EXP/ES/2015  32.47641
# 1  2040  LAS MEJORES ESTACIONES, S.A DE C.V  PL/902/EXP/ES/2015   20.3037
# 2  2041              DIAZ GAS, S.A. DE C.V.  PL/760/EXP/ES/2015  31.71947
# 3  2042         COMBU-EXPRESS, S.A. DE C.V.  PL/825/EXP/ES/2015  20.71413
# 4  2043              PETROMAX, S.A. DE C.V.  PL/585/EXP/ES/2015  26.03787
#
#          lng regular premium diesel Franquicia_Marca
# 0  -116.9214   21.99   26.99    NaN            PEMEX
# 1  -99.74484   23.89   25.49    NaN             PERC
# 2  -106.4514   18.87     NaN    NaN            PEMEX
# 3  -103.3042   23.99     NaN    NaN    Combu-Express
# 4  -98.29977   20.99     NaN    NaN      Petro Seven

# %%
# Guardamos en CSV
Gasolinerias_Precios.to_csv('../Data_CSV/places_&_prices_'+ Fecha +'.csv', sep = ',', encoding = 'utf-8-sig', 
                            index = False)

# %%
# Guardamos en CSV
Gasolinerias_Precios.to_json('Data/Price_Stations.json', orient='table', date_format = 'iso', index = False)

# %% [markdown]
# # SECCIÓN II:
#
# # Importador de datos de Estaciones de Servicio
#
# ### NOTA: Modificar el nombre del archivo para actualizar datos (1 vez cada mes)
#
# https://www.gob.mx/cre/articulos/precios-vigentes-de-gasolinas-y-diesel
#
# https://www.cre.gob.mx/da/Precios_promedio_diarios_y_mensuales_en_estaciones_de_servicio.xlsx

# %%
#
PreciosPromedioMensuales = pd.read_excel( 'https://www.cre.gob.mx/da/Precios_promedio_diarios_y_mensuales_en_estaciones_de_servicio.xlsx', 
                                          sheet_name = 'Cuadro 1.1', skiprows = 3 )

# URL del archivo
url = "https://www.cre.gob.mx/da/Precios_promedio_diarios_y_mensuales_en_estaciones_de_servicio.xlsx"
nombre_archivo = "Precios_PROMEDIO_CRE.xlsx"

# Descargar y guardar
response = requests.get(url)
with open(nombre_archivo, "wb") as f:
    f.write(response.content)

#PreciosPromedioMensuales = pd.read_csv('http://www.cre.gob.mx/da/PreciosPromedioMensuales.csv', encoding = 'latin-1', 
#                              skiprows = 1)

PreciosPromedioMensuales.tail()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 2>()
#       1 #
# ----> 2 PreciosPromedioMensuales = pd.read_excel( 'https://www.cre.gob.mx/da/Precios_promedio_diarios_y_mensuales_en_estaciones_de_servicio.xlsx',
#       3                                           sheet_name = 'Cuadro 1.1', skiprows = 3 )
#       5 # URL del archivo
#       6 url = "https://www.cre.gob.mx/da/Precios_promedio_diarios_y_mensuales_en_estaciones_de_servicio.xlsx"
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/site-packages/pandas/io/excel/_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
#     512         "Engine should not be specified when passing "
#     513         "an ExcelFile - ExcelFile already has the engine set"
#     514     )
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/site-packages/pandas/io/excel/_base.py:1563, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1561     ext = "xls"
#    1562 else:
# -> 1563     ext = inspect_excel_format(
#    1564         content_or_path=path_or_buffer, storage_options=storage_options
#    1565     )
#    1566     if ext is None:
#    1567         raise ValueError(
#    1568             "Excel file format cannot be determined, you must specify "
#    1569             "an engine manually."
#    1570         )
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/site-packages/pandas/io/excel/_base.py:1419, in inspect_excel_format(content_or_path, storage_options)
#    1416 if isinstance(content_or_path, bytes):
#    1417     content_or_path = BytesIO(content_or_path)
# -> 1419 with get_handle(
#    1420     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1421 ) as handle:
#    1422     stream = handle.handle
#    1423     stream.seek(0)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/site-packages/pandas/io/common.py:718, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     715     codecs.lookup_error(errors)
#     717 # open URLs
# --> 718 ioargs = _get_filepath_or_buffer(
#     719     path_or_buf,
#     720     encoding=encoding,
#     721     compression=compression,
#     722     mode=mode,
#     723     storage_options=storage_options,
#     724 )
#     726 handle = ioargs.filepath_or_buffer
#     727 handles: list[BaseBuffer]
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/site-packages/pandas/io/common.py:372, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     370 # assuming storage_options is to be interpreted as headers
#     371 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 372 with urlopen(req_info) as req:
#     373     content_encoding = req.headers.get("Content-Encoding", None)
#     374     if content_encoding == "gzip":
#     375         # Override compression based on Content-Encoding header
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/site-packages/pandas/io/common.py:274, in urlopen(*args, **kwargs)
#     268 """
#     269 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     270 the stdlib.
#     271 """
#     272 import urllib.request
# --> 274 return urllib.request.urlopen(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %%
# Seleccionamos datos de la serie de precios promedio diario
Serie_Precios = PreciosPromedioMensuales[[ 'Fecha', 'Gasolina Regular', 'Gasolina Premium', 'Diésel']]

Serie_Precios = Serie_Precios.rename(columns = { 'Gasolina Regular':'Gas87', 'Gasolina Premium':'Gas91', 'Diésel':'Diesel' })

Serie_Precios = Serie_Precios.dropna()


# Seleccionamos datos de la serie de precios promedio diario
#Serie_Precios = PreciosPromedioMensuales[['FechaCalendario', 'Gasolina mínimo 87 octanos.1', 
#                                          'Gasolina mínimo 91 octanos.1', 'Diésel.1']]

#Serie_Precios = Serie_Precios.rename(columns={ 'FechaCalendario':'Fecha', 'Gasolina mínimo 87 octanos.1':'Gas87',
#                                                  'Gasolina mínimo 91 octanos.1':'Gas91', 'Diésel.1':'Diesel' })

#Serie_Precios = Serie_Precios.dropna()

#

Serie_Precios.head()

# %%
# Convert to Datetime
Serie_Precios["Fecha"] = pd.to_datetime( Serie_Precios["Fecha"], format = '%d/%m/%Y' )
Serie_Precios = Serie_Precios.sort_values(by = 'Fecha', ascending = True).reset_index(drop = True)

# %%
#
Serie_Precios.tail()

# %%
# Guardamos en CSV
Serie_Precios.to_csv('../Data_CSV/Price_Time_Serie.csv', sep = ',', encoding = 'utf-8-sig', index = False)

# %%
# Guardamos en JSON
Serie_Precios.to_json('Data/Price_Time_Serie.json', orient = 'table', date_format = 'iso', index = False)
